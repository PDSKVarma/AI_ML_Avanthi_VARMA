# %% [markdown]
# <a href="https://colab.research.google.com/github/PDSKVarma/AI_ML_Avanthi_VARMA/blob/main/English_Words_EDA_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
df = pd.read_csv("unix-words.txt")

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df.rename(columns={'A':'words'},inplace=True)

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['words']= df["words"].fillna('')
df['cc'] = df["words"].apply(len)
df
# Out:
#              words  cc
# 0                a   1
# 1               aa   2
# 2              aal   3
# 3            aalii   5
# 4              aam   3
# ...            ...  ..
# 235880      zythem   6
# 235881      Zythia   6
# 235882      zythum   6
# 235883     Zyzomys   7
# 235884  Zyzzogeton  10
#
# [235885 rows x 2 columns]

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def cus_fun(x):
    summ = 0
    x.lower()
    z = list(x)
    for i in range(len(z)):
        n= z.pop()
        a_value =ord(n)-96
        summ = summ +a_value
    return summ

# %%
df['total_num']= df['words'].apply(cus_fun)

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235885 entries, 0 to 235884
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   words      235885 non-null  object
#  1   cc         235885 non-null  int64
#  2   total_num  235885 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 5.4+ MB

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df
# Out:
#              words  cc  total_num
# 0                a   1          1
# 1               aa   2          2
# 2              aal   3         14
# 3            aalii   5         32
# 4              aam   3         15
# ...            ...  ..        ...
# 235880      zythem   6         97
# 235881      Zythia   6         57
# 235882      zythum   6        113
# 235883     Zyzomys   7        117
# 235884  Zyzzogeton  10        147
#
# [235885 rows x 3 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df["words"]=="Acanthomeridae"]
# Out:
#               words  cc  total_num
# 762  Acanthomeridae  14         85

# %% [markdown]
# What is the highest possible value for a word?

# %%
df['total_num'].max()
# Out:
# 328

# %% [markdown]
# What is the highest possible length of a word

# %%
df['cc'].max()
# Out:
# 24

# %% [markdown]
# What is the value of the word with Value '317'

# %%
df.loc[df['total_num']==317]
# Out:
#                            words  cc  total_num
# 203040  thyroparathyroidectomize  24        317

# %% [markdown]
# What is the most common value?

# %%
max(df["total_num"].value_counts())
# Out:
# 2218

# %%
df["total_num"].value_counts()
# Out:
# 102    2218
# 107    2194
# 100    2185
# 108    2184
# 115    2171
#        ...
# 305       1
# 289       1
# 317       1
# 283       1
# 314       1
# Name: total_num, Length: 336, dtype: int64

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df["total_num"] == 107].min()
# Out:
# words        Agriochoerus
# cc                      5
# total_num             107
# dtype: object

# %%
df1 = df.loc[df['total_num'] == 107]
min(df1["words"],key = len)
#df1.loc[df1["words"] == df1["cc"].min()]
# Out:
# 'yezzy'

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df["Ratio"] = df['total_num']/df["cc"]
df
# Out:
#              words  cc  total_num      Ratio
# 0                a   1          1   1.000000
# 1               aa   2          2   1.000000
# 2              aal   3         14   4.666667
# 3            aalii   5         32   6.400000
# 4              aam   3         15   5.000000
# ...            ...  ..        ...        ...
# 235880      zythem   6         97  16.166667
# 235881      Zythia   6         57   9.500000
# 235882      zythum   6        113  18.833333
# 235883     Zyzomys   7        117  16.714286
# 235884  Zyzzogeton  10        147  14.700000
#
# [235885 rows x 4 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
max1 = df["Ratio"].max()
max1
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df.loc[df['Ratio'] == max1]
# Out:
#        words  cc  total_num  Ratio
# 234937     z   1         26   26.0

# %% [markdown]
# How many words have the ratio of 10

# %%
len(df.loc[df["Ratio"] == 10])
# Out:
# 3159

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
df2 = df.loc[df['Ratio'] == 10]
max(df2["total_num"])
# Out:
# 210

# %% [markdown]
# Of all the words with the value of 260, what has the loswest character count?

# %%
df3 = df.loc[df['total_num'] == 260]
min(df3["words"],key = len)
# Out:
# 'gastrohysteropexy'

# %%
df.loc[df["total_num"] == 260 & min(df["cc"])]
# Out:
#           words  cc  total_num  Ratio
# 684     Acacian   7          0    0.0
# 1538       Acis   4          0    0.0
# 1571     Acnida   6          0    0.0
# 2337     Adelia   6          0    0.0
# 4976      Aleck   5          0    0.0
# 5161      Algic   5          0    0.0
# 8638      Anice   5          0    0.0
# 11077     Apama   5          0    0.0
# 12404   Arcacea   7          0    0.0
# 19491    Beagle   6          0    0.0
# 20432    Belgae   6          0    0.0
# 20474     Bella   5          0    0.0
# 29443   Canacee   7          0    0.0
# 32101     Cecil   5          0    0.0
# 34440    Chicha   6          0    0.0
# 48093    Dacian   6          0    0.0
# 48856      Dave   4          0    0.0
# 48937      Daza   4          0    0.0
# 53359      Dido   4          0    0.0
# 61219      Emma   4          0    0.0
# 62362      Enid   4          0    0.0
# 65846       Eve   3          0    0.0
# 68666       Fay   3          0    0.0
# 74809    Galcha   6          0    0.0
# 77202      Gigi   4          0    0.0
# 81697    Haidee   6          0    0.0
# 81779     Hakka   5          0    0.0
# 88422       Hwa   3          0    0.0
# 100054      Jim   3          0    0.0
# 105427     Leif   4          0    0.0
# 105527     Lena   4          0    0.0
# 105625      Leo   3          0    0.0
# 111394      Mar   3          0    0.0
# 112834    Media   5          0    0.0
# 117875      Mod   3          0    0.0
# 122278            0          0    NaN
# 122865     Neal   4          0    0.0
# 128519            0          0    NaN
# 130295      Ole   3          0    0.0
# 149292      Poa   3          0    0.0
# 162946      Ram   3          0    0.0
# 169211     Rhea   4          0    0.0
# 172067    Sabia   5          0    0.0
# 172616     Saka   4          0    0.0
# 172635      Sal   3          0    0.0
# 181036      Sid   3          0    0.0
# 226686      Vai   3          0    0.0
# 227354     Veda   4          0    0.0
# 235070      Zea   3          0    0.0
